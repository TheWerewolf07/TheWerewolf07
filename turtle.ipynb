# %%
# importing turtle for graphics
import turtle

# forming the window screen
tut = turtle.Screen()

# background color blue
tut.bgcolor("Violet")

# object
pen = turtle.Turtle()

# speed of pen
pen.speed(10)

# object color
pen.color("Pink")

#object width
pen.width(10)
tut = turtle.Screen()

# code for symbol
# background C
for x in range(180):
    pen.forward(1)
    pen.right(1)
    
# up
pen.right(90)
pen.forward(50)

# right
pen.right(90)
pen.forward(130)

# down
pen.right(90)
pen.forward(50)
pen.left(90)

# forward C
for x in range(180):
    pen.backward(1)
    pen.right(1)
    
turtle.done()

# %%
import turtle
tut=turtle.Screen()
tut.bgcolor("Black")
pen=turtle.Turtle()
pen.speed(20)
pen.color("Red")
pen.width(5)
tut=turtle.Screen()

# %%
import turtle

pen= turtle.Turtle()

#pen.forward(100)
#pen.left(90)
#pen.forward(100)
#pen.left(90)
#pen.forward(100)
#pen.left(90)
#pen.forward(100)


pen.begin_fill()
pen.color("blue","cyan")
pen.forward(100)
pen.left(90)
pen.forward(100)
pen.left(90)
pen.forward(100)
pen.left(90)
pen.forward(100)

pen.penup()
pen.forward(150)
pen.pendown()


pen.forward(100)
pen.left(90)
pen.forward(100)
pen.left(90)
pen.forward(100)
pen.left(90)
pen.forward(100)
pen.end_fill()







turtle.done()
