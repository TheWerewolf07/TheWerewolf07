# %%
# PEMDAS which means parenthses,exponents,multiplication,division,addition and substraction

my_value= 2*((8+2)**2/5)-4
print(my_value)
# Out:
# 36.0

# %%
def f(x):
    return 2*x+1

x_values=[0,1,2,3]

for x in x_values:
    y=f(x)
    print(y)
# Out:
# 1
# 3
# 5
# 7

# %%
# !pip install sympy

# %%
from sympy import *

# %%
x=symbols('x')
f=x**2+1
plot(f)

# %%
from sympy.plotting import plot3d

x,y=symbols('x y')
f=2*x+3*y
plot3d(f)

# %%
summation=sum(2*i for i in range (1,8))
print(summation)
# Out:
# 56

# %%
x=[1,4,6,2]
n=len(x)

summation=sum(10*x[i] for i in range(0,n))
print(summation)
# Out:
# 130

# %%
# Exponents- Exponents multiply a number by itself a specified number of times. When you raise 2 to the third power
# which means multiplying three 2s together.

x=symbols('x')
expr=x**2/X**5
print(expr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 5>()
#       1 # Exponents- Exponents multiply a number by itself a specified number of times. When you raise 2 to the third power
#       2 # which means multiplying three 2s together.
#       4 x=symbols('x')
# ----> 5 expr=x**2/X**5
#       6 print(expr)
#
# NameError: name 'X' is not defined

# %%
x=symbols('x')
f=2*x+1
plot(f)
